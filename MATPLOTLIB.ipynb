# %% [markdown]
# #  Matplotib.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.arange(0,10)
y=np.arange(11,21)
z=np.random.rand(10)
t=np.random.randn(10)
x
y
z
t
# Out:
# array([ 0.83567809,  0.34597519, -1.70688562,  0.96671501,  0.26251865,
#        -0.17961905,  0.29192484, -0.81988656, -0.07805298, -0.82245545])

# %%
plt.plot(x,z)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')

# %% [markdown]
# # Set Font Properties for Title and Labels
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
#Set font properties for the title and labels:

import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Add Grid Lines to a Plot
# With Pyplot, you can use the grid() function to add grid lines to the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
plt.scatter(x,z)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
plt.plot(x,t)

# %%
plt.subplot(3,1,1)
plt.plot(x,z)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')
plt.subplot(3,1,2)
plt.plot(x,y)
plt.subplot(3,1,3)
plt.plot(x,t)

# %%
plt.subplot(2,2,1)
plt.plot(x,z)
plt.subplot(2,2,2)
plt.plot(x,z)
plt.subplot(2,2,3)
plt.plot(x,z)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 3)]

# %%
data
# Out:
# [array([ 2.13396346, -0.06332502,  0.26353856, -0.73855763, -0.07404723,
#          0.98936078,  0.54646815, -0.82760603, -1.50763375, -1.56050668,
#         -1.57678819, -2.84747188,  0.65557739,  1.98646482,  0.48687206,
#          1.7080377 ,  0.8457955 , -3.08069775,  0.14338502,  0.57723775,
#         -0.66072349,  1.40689303,  1.17230814, -0.77280454,  0.68267553,
#          2.32784236,  0.31568972,  1.15536893,  0.48780497, -0.02541057,
#          0.19148002,  0.07934301, -0.34747288,  0.12617372,  2.14151062,
#         -0.09532685,  0.0385693 ,  0.48470534,  0.93701461,  0.21803915,
#         -0.86758972, -0.4434013 ,  0.68654134, -0.95239361, -0.14288227,
#          0.19000583, -2.2044093 , -0.54566111, -0.48471169, -0.54601901,
#         -0.16597207,  0.8153593 , -1.04950891,  1.08745044,  0.17504081,
#          0.83094627, -0.75303752,  1.73769858, -1.10323592, -0.30561313,
#         -0.88302446, -0.60301009, -1.1069132 , -0.67541052,  0.99884077,
#         -0.04048842,  2.08961663,  0.31195627, -0.10347844,  0.66271605,
